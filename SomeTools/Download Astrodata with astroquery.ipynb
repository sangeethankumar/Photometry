# %%
# %pip install astroquery pandas

# %% [markdown]
# MAST (Mikulski Archive for Space Telescopes) is a NASA-funded digital archive that stores and provides access to astronomical data primarily from space-based missions, focusing on optical, ultraviolet, and near-infrared spectra. It supports research by offering various tools for querying and analyzing this extensive dataset.
#
# `astroquery.mast` has services for Observational queries, Mission specific queries, and Catalog queries
#
# ## Observation Queries
#
# ### Positional Queries

# %%
from astroquery.mast import Observations
import pandas as pd

Observations.query_region_async?
# Out:
# C:\Users\sange\AppData\Local\Temp\ipykernel_9296\3312607385.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Signature:
# Observations.query_region_async(
#     self,
#     coordinates,
#     *,
#     radius=<Quantity 0.2 deg>,
#     pagesize=None,
#     page=None,
# )
# Docstring:
# Given a sky position and radius, returns a list of MAST observations.
# See column documentation `here <https://mast.stsci.edu/api/v0/_c_a_o_mfields.html>`__.
#
# Parameters
# ----------
# coordinates : str or `~astropy.coordinates` object
#     The target around which to search. It may be specified as a
#     string or as the appropriate `~astropy.coordinates` object.
# radius : str or `~astropy.units.Quantity` object, optional
#     Default 0.2 degrees.
#     The string must be parsable by `~astropy.coordinates.Angle`. The
#     appropriate `~astropy.units.Quantity` object from
#     `~astropy.units` may also be used. Defaults to 0.2 deg.
# pagesize : int, optional
#     Default None.
#     Can be used to override the default pagesize for (set in configs) this query only.
#     E.g. when using a slow internet connection.
# page : int, optional
#     Default None.
#     Can be used to override the default behavior of all results being returned to
#     obtain a specific page of results.
#
# Returns
# -------
# response : list of `~requests.Response`
# File:      c:\users\sange\anaconda3\envs\pythonproject\lib\site-packages\astroquery\mast\observations.py
# Type:      function

# %%
# Kepler 51
obs_table = Observations.query_region("286.36043 40.94766")
obs_table[:10]
# Out:
# WARNING: InputWarning: Coordinate string is being interpreted as an ICRS coordinate provided in degrees. [astroquery.utils.commons]
# <Table masked=True length=10>
# intentType obs_collection provenance_name ...  srcDen  obsid        distance
#    str7        str11           str12      ... float64   str9        float64
# ---------- -------------- --------------- ... ------- -------- -----------------
#    science           TESS            SPOC ...     nan 27463640               0.0
#    science           TESS            SPOC ...     nan 27699645               0.0
#    science           TESS            SPOC ...     nan 62431376               0.0
#    science           TESS            SPOC ...     nan 62870786               0.0
#    science           TESS            SPOC ...     nan 87826122               0.0
#    science           TESS            SPOC ...     nan 92616902               0.0
#    science           TESS            SPOC ...     nan 95133363 236.1836231921835
#    science           TESS            SPOC ...     nan 62792436 555.6918340486586
#    science           TESS            SPOC ...     nan 87745997 555.6918340486586
#    science           TESS            SPOC ...     nan 91545801 555.6918340486586

# %%
obs = obs_table.to_pandas()
obs.columns
# Out:
# Index(['intentType', 'obs_collection', 'provenance_name', 'instrument_name',
#        'project', 'filters', 'wavelength_region', 'target_name',
#        'target_classification', 'obs_id', 's_ra', 's_dec', 'dataproduct_type',
#        'proposal_pi', 'calib_level', 't_min', 't_max', 't_exptime', 'em_min',
#        'em_max', 'obs_title', 't_obs_release', 'proposal_id', 'proposal_type',
#        'sequence_number', 's_region', 'jpegURL', 'dataURL', 'dataRights',
#        'mtFlag', 'srcDen', 'obsid', 'distance'],
#       dtype='object')

# %%
list(obs.instrument_name.values)
# Out:
# ['Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'IRAC',
#  'IRAC',
#  'IRAC',
#  'IRAC',
#  'IRAC',
#  'IRAC',
#  'IRAC',
#  'IRAC',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'GPC1',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Photometer',
#  'Photometer',
#  'Kepler Photometer',
#  'Kepler',
#  'Kepler',
#  'Kepler',
#  'Kepler Photometer',
#  ...]

# %% [markdown]
# ### Observation Query

# %%
obs_table = Observations.query_criteria(proposal_pi="Pontoppidan*", instrument_name="MIRI*")
obs_table
# Out:
# <Table masked=True length=135>
# intentType obs_collection provenance_name ...  srcDen   obsid     objID
#    str7         str4            str8      ... float64    str9      str9
# ---------- -------------- --------------- ... ------- --------- ---------
#    science           JWST         CALJWST ...     nan  87602158 347835607
#    science           JWST         CALJWST ...     nan  87602164 347835696
#    science           JWST         CALJWST ...     nan  87602169 347835723
#    science           JWST         CALJWST ...     nan  87602308 349830273
#    science           JWST         CALJWST ...     nan  87602309 349830332
#    science           JWST         CALJWST ...     nan  87602311 349830394
#    science           JWST         CALJWST ...     nan  87602313 349830452
#    science           JWST         CALJWST ...     nan  87602443 344133325
#    science           JWST         CALJWST ...     nan  87602445 344185624
#    science           JWST         CALJWST ...     nan  87602447 344133465
#        ...            ...             ... ...     ...       ...       ...
#    science           HLSP        JWST-ERO ...     nan 149064057 269360777
#    science           HLSP        JWST-ERO ...     nan 149064071 269360789
#    science           HLSP        JWST-ERO ...     nan 149064083 269360794
#    science           HLSP        JWST-ERO ...     nan 149064094 269360803
#    science           HLSP        JWST-ERO ...     nan 149064109 269360814
#    science           HLSP        JWST-ERO ...     nan 149064116 269360823
#    science           HLSP        JWST-ERO ...     nan 149064126 269360831
#    science           HLSP        JWST-ERO ...     nan 149064140 269360843
#    science           HLSP        JWST-ERO ...     nan 149064151 269360852
#    science           HLSP        JWST-ERO ...     nan 149064161 269360858
